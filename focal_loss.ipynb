# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/leaf_bce_hybrid/blob/main/focal_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. SETUP AND DATA DOWNLOAD ---
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm

# Extract Dataset
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# --- 2. CONFIGURATION ---
DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LEARNING_RATE = 5e-5
NUM_EPOCHS = 130
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- 3. LOSS IMPLEMENTATION ---
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        return loss.mean()

# --- 4. DATASET CLASS ---
class LeafDiseaseDataset(Dataset):
    def __init__(self, root_dir, img_size=IMG_SIZE, augment=False):
        self.images_dir = os.path.join(root_dir, "images")
        self.masks_dir = os.path.join(root_dir, "masks")
        self.img_size = img_size
        self.image_files = sorted([f for f in os.listdir(self.images_dir) if f.endswith('.jpg')])
        self.augment = augment
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225])

    def __len__(self): return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.images_dir, img_name)
        mask_path = os.path.join(self.masks_dir, img_name.replace(".jpg", ".png"))

        image = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")

        image = image.resize(self.img_size)
        mask = mask.resize(self.img_size, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand() > 0.5:
                image = transforms.functional.hflip(image)
                mask = transforms.functional.hflip(mask)
            if np.random.rand() > 0.5:
                image = transforms.functional.vflip(image)
                mask = transforms.functional.vflip(mask)

        image = transforms.ToTensor()(image)
        image = self.normalize(image)

        mask = transforms.ToTensor()(mask)
        mask = (mask > 0).float()

        return image, mask

# --- 5. DATASET SPLIT ---
torch.manual_seed(42)
full_dataset = LeafDiseaseDataset(DATASET_PATH)
train_size = int(0.75 * len(full_dataset))

indices = torch.randperm(len(full_dataset))
train_indices = indices[:train_size]
val_indices = indices[train_size:]

train_dataset = torch.utils.data.Subset(
    LeafDiseaseDataset(DATASET_PATH, augment=True),
    train_indices
)

val_dataset = torch.utils.data.Subset(
    LeafDiseaseDataset(DATASET_PATH, augment=False),
    val_indices
)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# --- 6. MODEL ---
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.2),
            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )
    def forward(self, x): return self.conv(x)

class DecoderBlock(nn.Module):
    def __init__(self, in_ch, skip_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, in_ch//2, 2, 2)
        self.conv = DoubleConv(in_ch//2 + skip_ch, out_ch)

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], dim=1)
        return self.conv(x)

class ResNet50UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.up1 = DecoderBlock(2048,1024,512)
        self.up2 = DecoderBlock(512,512,256)
        self.up3 = DecoderBlock(256,256,128)
        self.up4 = DecoderBlock(128,64,64)

        self.final_up = nn.ConvTranspose2d(64,32,2,2)
        self.final = nn.Conv2d(32,1,1)

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.up1(x4,x3)
        d2 = self.up2(d1,x2)
        d3 = self.up3(d2,x1)
        d4 = self.up4(d3,x0)

        return self.final(self.final_up(d4))

# --- 7. METRIC ---
def mean_iou(preds, masks, eps=1e-6):
    preds = (torch.sigmoid(preds) > 0.5).float()
    intersection = (preds * masks).sum((1,2,3))
    union = preds.sum((1,2,3)) + masks.sum((1,2,3)) - intersection
    return ((intersection+eps)/(union+eps)).mean()

# --- 8. TRAINING ---
model = ResNet50UNet().to(DEVICE)
criterion = FocalLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

history = {"train_loss": [], "val_loss": [], "train_iou": [], "val_iou": []}
best_iou = 0

for epoch in range(NUM_EPOCHS):
    model.train()
    t_loss, t_iou = 0, 0

    for images, masks in tqdm(train_loader, leave=False):
        images, masks = images.to(DEVICE), masks.to(DEVICE)

        outputs = model(images)
        loss = criterion(outputs, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        t_loss += loss.item()
        t_iou += mean_iou(outputs, masks).item()

    model.eval()
    v_loss, v_iou = 0, 0

    with torch.no_grad():
        for images, masks in val_loader:
            images, masks = images.to(DEVICE), masks.to(DEVICE)

            outputs = model(images)
            v_loss += criterion(outputs, masks).item()
            v_iou += mean_iou(outputs, masks).item()

    history["train_loss"].append(t_loss/len(train_loader))
    history["val_loss"].append(v_loss/len(val_loader))
    history["train_iou"].append(t_iou/len(train_loader))
    history["val_iou"].append(v_iou/len(val_loader))

    print(f"Epoch {epoch+1}: "
      f"T-Loss: {history['train_loss'][-1]:.4f} | "
      f"V-Loss: {history['val_loss'][-1]:.4f} | "
      f"T-IoU: {history['train_iou'][-1]:.4f} | "
      f"V-IoU: {history['val_iou'][-1]:.4f}")
    if history["val_iou"][-1] > best_iou:
        best_iou = history["val_iou"][-1]
        torch.save(model.state_dict(), "best_model.pth")
        print("--->>>Best model saved!!")

# --- 9. PLOTS ---
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.title("Loss Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history["train_iou"], label="Train IoU")
plt.plot(history["val_iou"], label="Val IoU")
plt.title("IoU Curve")
plt.legend()

plt.show()

# --- 10. VISUALIZATION ---
def visualize_results(model, dataset, n_samples=5):
    model.eval()
    fig, axes = plt.subplots(n_samples, 3, figsize=(15, 5*n_samples))

    for i in range(n_samples):
        idx = np.random.randint(len(dataset))
        image, mask = dataset[idx]

        with torch.no_grad():
            pred = model(image.unsqueeze(0).to(DEVICE))
            pred = (torch.sigmoid(pred) > 0.5).float().cpu().squeeze()

        img_disp = image.permute(1,2,0).numpy()
        img_disp = img_disp * np.array([0.229,0.224,0.225]) + np.array([0.485,0.456,0.406])
        img_disp = np.clip(img_disp,0,1)

        axes[i,0].imshow(img_disp)
        axes[i,0].set_title("Image")

        axes[i,1].imshow(mask.squeeze(), cmap='gray')
        axes[i,1].set_title("GT")

        axes[i,2].imshow(pred, cmap='gray')
        axes[i,2].set_title("Prediction")

        for ax in axes[i]:
            ax.axis("off")

    plt.tight_layout()
    plt.show()

visualize_results(model, val_dataset)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# leaf-disease-segmentation-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Epoch 1: T-Loss: 0.0263 | V-Loss: 0.0125 | T-IoU: 0.4833 | V-IoU: 0.6563
# --->>>Best model saved!!
# Epoch 2: T-Loss: 0.0116 | V-Loss: 0.0079 | T-IoU: 0.6396 | V-IoU: 0.6966
# --->>>Best model saved!!
# Epoch 3: T-Loss: 0.0088 | V-Loss: 0.0072 | T-IoU: 0.6768 | V-IoU: 0.7152
# --->>>Best model saved!!
# Epoch 4: T-Loss: 0.0075 | V-Loss: 0.0062 | T-IoU: 0.7032 | V-IoU: 0.7241
# --->>>Best model saved!!
# Epoch 5: T-Loss: 0.0069 | V-Loss: 0.0055 | T-IoU: 0.7149 | V-IoU: 0.7503
# --->>>Best model saved!!
# Epoch 6: T-Loss: 0.0063 | V-Loss: 0.0052 | T-IoU: 0.7341 | V-IoU: 0.7653
# --->>>Best model saved!!
# Epoch 7: T-Loss: 0.0059 | V-Loss: 0.0049 | T-IoU: 0.7456 | V-IoU: 0.7652
# Epoch 8: T-Loss: 0.0058 | V-Loss: 0.0050 | T-IoU: 0.7510 | V-IoU: 0.7776
# --->>>Best model saved!!
# Epoch 9: T-Loss: 0.0050 | V-Loss: 0.0047 | T-IoU: 0.7701 | V-IoU: 0.7859
# --->>>Best model saved!!
# Epoch 10: T-Loss: 0.0047 | V-Loss: 0.0045 | T-IoU: 0.7775 | V-IoU: 0.7894
# --->>>Best model saved!!
# Epoch 11: T-Loss: 0.0045 | V-Loss: 0.0042 | T-IoU: 0.7846 | V-IoU: 0.7963
# --->>>Best model saved!!
# Epoch 12: T-Loss: 0.0045 | V-Loss: 0.0042 | T-IoU: 0.7848 | V-IoU: 0.8015
# --->>>Best model saved!!
# Epoch 13: T-Loss: 0.0041 | V-Loss: 0.0041 | T-IoU: 0.7954 | V-IoU: 0.8031
# --->>>Best model saved!!
# Epoch 14: T-Loss: 0.0041 | V-Loss: 0.0040 | T-IoU: 0.7985 | V-IoU: 0.8064
# --->>>Best model saved!!
# Epoch 15: T-Loss: 0.0039 | V-Loss: 0.0038 | T-IoU: 0.8048 | V-IoU: 0.8129
# --->>>Best model saved!!
# Epoch 16: T-Loss: 0.0038 | V-Loss: 0.0039 | T-IoU: 0.8072 | V-IoU: 0.8145
# --->>>Best model saved!!
# Epoch 17: T-Loss: 0.0037 | V-Loss: 0.0037 | T-IoU: 0.8120 | V-IoU: 0.8202
# --->>>Best model saved!!
# Epoch 18: T-Loss: 0.0036 | V-Loss: 0.0036 | T-IoU: 0.8148 | V-IoU: 0.8171
# Epoch 19: T-Loss: 0.0035 | V-Loss: 0.0036 | T-IoU: 0.8216 | V-IoU: 0.8249
# --->>>Best model saved!!
# Epoch 20: T-Loss: 0.0034 | V-Loss: 0.0035 | T-IoU: 0.8234 | V-IoU: 0.8276
# --->>>Best model saved!!
# Epoch 21: T-Loss: 0.0033 | V-Loss: 0.0034 | T-IoU: 0.8286 | V-IoU: 0.8313
# Epoch 69: T-Loss: 0.0019 | V-Loss: 0.0026 | T-IoU: 0.8910 | V-IoU: 0.8807
# Epoch 70: T-Loss: 0.0019 | V-Loss: 0.0026 | T-IoU: 0.8912 | V-IoU: 0.8821
# --->>>Best model saved!!
# Epoch 71: T-Loss: 0.0019 | V-Loss: 0.0026 | T-IoU: 0.8924 | V-IoU: 0.8838
# --->>>Best model saved!!
# Epoch 72: T-Loss: 0.0018 | V-Loss: 0.0026 | T-IoU: 0.8932 | V-IoU: 0.8821
# Epoch 73: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8939 | V-IoU: 0.8833
# Epoch 74: T-Loss: 0.0022 | V-Loss: 0.0026 | T-IoU: 0.8791 | V-IoU: 0.8757
# Epoch 75: T-Loss: 0.0019 | V-Loss: 0.0025 | T-IoU: 0.8899 | V-IoU: 0.8814
# Epoch 76: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8940 | V-IoU: 0.8826
# Epoch 77: T-Loss: 0.0018 | V-Loss: 0.0024 | T-IoU: 0.8952 | V-IoU: 0.8846
# --->>>Best model saved!!
# Epoch 78: T-Loss: 0.0018 | V-Loss: 0.0026 | T-IoU: 0.8980 | V-IoU: 0.8857
# --->>>Best model saved!!
# Epoch 79: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8977 | V-IoU: 0.8872
# --->>>Best model saved!!
# Epoch 80: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8979 | V-IoU: 0.8861
# Epoch 81: T-Loss: 0.0017 | V-Loss: 0.0027 | T-IoU: 0.8990 | V-IoU: 0.8828
# Epoch 82: T-Loss: 0.0017 | V-Loss: 0.0025 | T-IoU: 0.8996 | V-IoU: 0.8880
# --->>>Best model saved!!
# Epoch 83: T-Loss: 0.0017 | V-Loss: 0.0024 | T-IoU: 0.8997 | V-IoU: 0.8891
# --->>>Best model saved!!
# Epoch 84: T-Loss: 0.0021 | V-Loss: 0.0028 | T-IoU: 0.8875 | V-IoU: 0.8795
# Epoch 85: T-Loss: 0.0019 | V-Loss: 0.0028 | T-IoU: 0.8905 | V-IoU: 0.8812
# Epoch 86: T-Loss: 0.0018 | V-Loss: 0.0026 | T-IoU: 0.8970 | V-IoU: 0.8878
# Epoch 87: T-Loss: 0.0017 | V-Loss: 0.0026 | T-IoU: 0.9005 | V-IoU: 0.8883
# Epoch 88: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8999 | V-IoU: 0.8887
# Epoch 89: T-Loss: 0.0017 | V-Loss: 0.0025 | T-IoU: 0.9019 | V-IoU: 0.8885
# Epoch 90: T-Loss: 0.0017 | V-Loss: 0.0026 | T-IoU: 0.9031 | V-IoU: 0.8911
# --->>>Best model saved!!
# Epoch 91: T-Loss: 0.0016 | V-Loss: 0.0026 | T-IoU: 0.9041 | V-IoU: 0.8914
# --->>>Best model saved!!
# Epoch 92: T-Loss: 0.0016 | V-Loss: 0.0026 | T-IoU: 0.9056 | V-IoU: 0.8923
# --->>>Best model saved!!
# Epoch 93: T-Loss: 0.0016 | V-Loss: 0.0026 | T-IoU: 0.9049 | V-IoU: 0.8927
# --->>>Best model saved!!
# Epoch 94: T-Loss: 0.0016 | V-Loss: 0.0027 | T-IoU: 0.9051 | V-IoU: 0.8925
# Epoch 95: T-Loss: 0.0016 | V-Loss: 0.0024 | T-IoU: 0.9064 | V-IoU: 0.8944
# --->>>Best model saved!!
# Epoch 96: T-Loss: 0.0016 | V-Loss: 0.0025 | T-IoU: 0.9068 | V-IoU: 0.8947
# --->>>Best model saved!!
# Epoch 97: T-Loss: 0.0016 | V-Loss: 0.0025 | T-IoU: 0.9067 | V-IoU: 0.8939
# Epoch 98: T-Loss: 0.0016 | V-Loss: 0.0025 | T-IoU: 0.9072 | V-IoU: 0.8951
# --->>>Best model saved!!
# Epoch 99: T-Loss: 0.0017 | V-Loss: 0.0027 | T-IoU: 0.9019 | V-IoU: 0.8869
# Epoch 100: T-Loss: 0.0018 | V-Loss: 0.0025 | T-IoU: 0.8976 | V-IoU: 0.8909
# Epoch 101: T-Loss: 0.0016 | V-Loss: 0.0024 | T-IoU: 0.9044 | V-IoU: 0.8933
# Epoch 102: T-Loss: 0.0016 | V-Loss: 0.0024 | T-IoU: 0.9072 | V-IoU: 0.8947
# Epoch 103: T-Loss: 0.0015 | V-Loss: 0.0025 | T-IoU: 0.9090 | V-IoU: 0.8941
# Epoch 104: T-Loss: 0.0015 | V-Loss: 0.0026 | T-IoU: 0.9105 | V-IoU: 0.8966
# --->>>Best model saved!!
# Epoch 105: T-Loss: 0.0015 | V-Loss: 0.0026 | T-IoU: 0.9108 | V-IoU: 0.8978
# --->>>Best model saved!!
# Epoch 106: T-Loss: 0.0015 | V-Loss: 0.0027 | T-IoU: 0.9110 | V-IoU: 0.8965
# Epoch 107: T-Loss: 0.0017 | V-Loss: 0.0029 | T-IoU: 0.9043 | V-IoU: 0.8859
# Epoch 108: T-Loss: 0.0017 | V-Loss: 0.0026 | T-IoU: 0.9017 | V-IoU: 0.8917
# Epoch 109: T-Loss: 0.0016 | V-Loss: 0.0027 | T-IoU: 0.9077 | V-IoU: 0.8908
# Epoch 110: T-Loss: 0.0017 | V-Loss: 0.0024 | T-IoU: 0.9005 | V-IoU: 0.8950
# Epoch 111: T-Loss: 0.0018 | V-Loss: 0.0023 | T-IoU: 0.9012 | V-IoU: 0.8945
# Epoch 112: T-Loss: 0.0016 | V-Loss: 0.0023 | T-IoU: 0.9058 | V-IoU: 0.8968
# Epoch 113: T-Loss: 0.0015 | V-Loss: 0.0022 | T-IoU: 0.9092 | V-IoU: 0.8957
# Epoch 114: T-Loss: 0.0015 | V-Loss: 0.0022 | T-IoU: 0.9103 | V-IoU: 0.8998
# --->>>Best model saved!!
# Epoch 115: T-Loss: 0.0015 | V-Loss: 0.0023 | T-IoU: 0.9117 | V-IoU: 0.8998
# --->>>Best model saved!!
# Epoch 116: T-Loss: 0.0015 | V-Loss: 0.0022 | T-IoU: 0.9131 | V-IoU: 0.9001
# --->>>Best model saved!!
# Epoch 117: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9139 | V-IoU: 0.9010
# --->>>Best model saved!!
# Epoch 118: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9147 | V-IoU: 0.9011
# --->>>Best model saved!!
# Epoch 119: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9159 | V-IoU: 0.9028
# --->>>Best model saved!!
# Epoch 120: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9150 | V-IoU: 0.9023
# Epoch 121: T-Loss: 0.0015 | V-Loss: 0.0024 | T-IoU: 0.9124 | V-IoU: 0.8972
# Epoch 122: T-Loss: 0.0016 | V-Loss: 0.0025 | T-IoU: 0.9082 | V-IoU: 0.8961
# Epoch 123: T-Loss: 0.0015 | V-Loss: 0.0023 | T-IoU: 0.9132 | V-IoU: 0.9016
# Epoch 124: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9143 | V-IoU: 0.9030
# --->>>Best model saved!!
# Epoch 125: T-Loss: 0.0014 | V-Loss: 0.0023 | T-IoU: 0.9158 | V-IoU: 0.9024
# Epoch 126: T-Loss: 0.0019 | V-Loss: 0.0023 | T-IoU: 0.8962 | V-IoU: 0.8959
# Epoch 127: T-Loss: 0.0016 | V-Loss: 0.0025 | T-IoU: 0.9064 | V-IoU: 0.8968
# Epoch 128: T-Loss: 0.0015 | V-Loss: 0.0025 | T-IoU: 0.9108 | V-IoU: 0.9003
# Epoch 129: T-Loss: 0.0014 | V-Loss: 0.0026 | T-IoU: 0.9141 | V-IoU: 0.9019
# Epoch 130: T-Loss: 0.0014 | V-Loss: 0.0025 | T-IoU: 0.9151 | V-IoU: 0.9031
# --->>>Best model saved!!
# Epoch 131: T-Loss: 0.0014 | V-Loss: 0.0026 | T-IoU: 0.9163 | V-IoU: 0.9030
# Epoch 132: T-Loss: 0.0014 | V-Loss: 0.0026 | T-IoU: 0.9174 | V-IoU: 0.9043
# --->>>Best model saved!!
# Epoch 133: T-Loss: 0.0014 | V-Loss: 0.0025 | T-IoU: 0.9185 | V-IoU: 0.9050
# --->>>Best model saved!!
# Epoch 134: T-Loss: 0.0013 | V-Loss: 0.0026 | T-IoU: 0.9192 | V-IoU: 0.9048
# Epoch 135: T-Loss: 0.0014 | V-Loss: 0.0025 | T-IoU: 0.9193 | V-IoU: 0.9045
# Epoch 136: T-Loss: 0.0013 | V-Loss: 0.0026 | T-IoU: 0.9198 | V-IoU: 0.9057
# --->>>Best model saved!!
# Epoch 137: T-Loss: 0.0015 | V-Loss: 0.0029 | T-IoU: 0.9141 | V-IoU: 0.8980
# Epoch 138: T-Loss: 0.0014 | V-Loss: 0.0024 | T-IoU: 0.9151 | V-IoU: 0.9041
# Epoch 139: T-Loss: 0.0014 | V-Loss: 0.0025 | T-IoU: 0.9184 | V-IoU: 0.9049
# Epoch 140: T-Loss: 0.0013 | V-Loss: 0.0024 | T-IoU: 0.9202 | V-IoU: 0.9061
# --->>>Best model saved!!
